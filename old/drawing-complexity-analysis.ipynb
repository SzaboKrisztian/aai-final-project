# %%
# %load_ext autoreload
# %autoreload 2
from utils import extract_random_entries, complexity_score, render_single, extract_best_entries
import pandas as pd
from IPython.display import display, Image

files = ['./dataset/car.ndjson']#, './dataset/bicycle.ndjson']
df = pd.concat([extract_best_entries(file, None, recognized=True) for file in files], ignore_index=True).sort_values(by='complexity', ascending=False)
print(f'Loaded {len(df)} entries from {files}')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loaded 160789 entries from ['./dataset/car.ndjson']

# %%
num_pics = 100
step = len(df) // num_pics

img_params = {
    'magnification': 4,
    'resolution': 128,
    'invert_color': False,
    'stroke_width_scale': 2
}

print(df['complexity'].describe())

for i in range(0, len(df), step):
    img = df['drawing'].iloc[i]
    display(Image(render_single(img)))
# Out:
# count    160789.000000
# mean         50.984246
# std          14.655203
# min           2.000000
# 25%          41.000000
# 50%          49.000000
# 75%          58.000000
# max         265.000000
# Name: complexity, dtype: float64
