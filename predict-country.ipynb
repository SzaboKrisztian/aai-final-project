# %%
# %load_ext autoreload
# %autoreload 2
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.multiclass import OneVsRestClassifier
from sklearn.neural_network import MLPClassifier
from itertools import repeat
import time, os, joblib
import pandas as pd
from utils import generate_pixel_columns, extract_best_entries, extract_first_entries, equalize_by

# categories = ['car']
categories = ['ambulance','bed','bench','bread','castle','cell phone','chair','church','coffee cup','crown','cruise ship','cup','dishwasher','dresser','eye','face',
    'fan','fire hydrant','fish','hammer','hat','helicopter','ice cream','lantern','passport','pickup truck','pillow','power outlet','sailboat','sandwich','snowman',
    'star','strawberry','suitcase','table','telephone','traffic light','watermelon','wine glass']

image_gen_params = {
    'magnification': 1,
    'resolution': 32,
    'invert_color': True,
    'stroke_width_scale': 1
}

root = './countries'
if not os.path.exists(root):
    os.makedirs(root)

done = 0
for category in categories:
    t0 = time.time()
    print(f'Processing "{category}" ({done + 1}/{len(categories)}):')
    folder = f'{root}/{category}'
    if not os.path.exists(folder):
        os.makedirs(folder)
    df = extract_first_entries(f'./dataset/{category}.ndjson', recognized=True)
    df = equalize_by(df, 'countrycode')
    print(f"Extracted {len(df)} entries from category {category}")
    print(f"Retained {len(df['countrycode'].value_counts())} countries")
    df = generate_pixel_columns(df, **image_gen_params)

    train_amt = int(len(df) * .9)

    train = df[:train_amt]
    test = df[train_amt:]

    train = train.reset_index(drop=True)
    test = test.reset_index(drop=True)

    print(f'Train: {len(train)} entries, test: {len(test)} entries.')

    y = train['countrycode'].to_numpy()
    X = train.filter(regex='pixel.+').to_numpy()
    print("Done generating features and target")

    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    pca = PCA(.85)
    X = pca.fit_transform(X)
    print(f'PCA & standardization done. Keeping {pca.n_components_} features')

    classifier = MLPClassifier(hidden_layer_sizes=tuple(repeat(int(pca.n_components_ * 1.2), 3)), solver='lbfgs', alpha=1e-07)
    start = time.time()
    model = OneVsRestClassifier(classifier, n_jobs=-1).fit(X, y)
    end = time.time()
    print(f"Done training model in {'{:.2f}'.format(end - start)}s")
    joblib.dump(model, folder + '/model')
    joblib.dump(pca, folder + '/pca')
    joblib.dump(scaler, folder + '/scaler')
    print("Done saving model, pca, and scaler to disk")

    test2 = test.filter(regex='pixel.+').to_numpy()
    test2 = scaler.transform(test2)
    test2 = pca.transform(test2)
    prediction = model.predict(test2)

    countries = list(test['countrycode'].value_counts().keys())
    counts = {}
    for idx in range(len(test)):
        country = test['countrycode'].iloc[idx]
        entry_score = counts.get(country, (0, 0))
        entry_score = (entry_score[0] + 1 if prediction[idx] == country else entry_score[0], entry_score[1] + 1)
        counts[country] = entry_score
    scores = {}
    for country in countries:
        scores[country] = (counts[country][0] / counts[country][1]) * 100

    scores = [(k, v) for k, v in scores.items()]
    scores.sort(key=lambda e : e[1], reverse=True)
    threshold = 100 / len(countries)

    out = []

    out.append(f'Category "{category}"\n')
    out.append(str(image_gen_params))
    out.append(str(scores) + '\n')

    out.append(f'Scores greater than {"{:.2f}".format(threshold)}% (random chance):')
    for entry in scores:
        if entry[1] > threshold:
            out.append(f'  {entry[0]}: {"{:.2f}".format(entry[1])}%')

    from sklearn.metrics import accuracy_score
    acc_score = accuracy_score(test['countrycode'].values.tolist(), prediction)
    out.append(f"Overall accuracy: {'{:.2f}'.format(acc_score)}%\n")

    out = '\n'.join(out)
    with open(folder + '/stats', 'w') as f:
        f.write(out)

    print(out)

    duration = time.time() - t0
    print(f"Finished processing cateogory in {int(duration // 60)}m{int(duration % 60)}s")
    done += 1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Processing "ambulance" (1/39):
# Extracted 22000 entries from category ambulance
# Retained 22 countries
# Train: 19800 entries, test: 2200 entries.
# Done generating features and target
# PCA & standardization done. Keeping 530 features
# Done training model in 582.05s
# Done saving model, pca, and scaler to disk
# Category "ambulance"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('TH', 14.285714285714285), ('KR', 12.62135922330097), ('SA', 12.612612612612612), ('IN', 10.784313725490197), ('FI', 10.1010101010101), ('HU', 9.278350515463918), ('CA', 9.090909090909092), ('NL', 8.88888888888889), ('GB', 7.8431372549019605), ('PH', 7.446808510638298), ('BR', 6.024096385542169), ('CZ', 5.555555555555555), ('FR', 5.3097345132743365), ('RU', 5.263157894736842), ('AU', 5.128205128205128), ('PL', 4.958677685950414), ('US', 4.3478260869565215), ('IT', 3.3333333333333335), ('SE', 3.1914893617021276), ('RO', 3.1578947368421053), ('ID', 2.2222222222222223), ('DE', 1.7699115044247788)]
#
# Scores greater than 4.55% (random chance):
#   TH: 14.29%
#   KR: 12.62%
#   SA: 12.61%
#   IN: 10.78%
#   FI: 10.10%
#   HU: 9.28%
#   CA: 9.09%
#   NL: 8.89%
#   GB: 7.84%
#   PH: 7.45%
#   BR: 6.02%
#   CZ: 5.56%
#   FR: 5.31%
#   RU: 5.26%
#   AU: 5.13%
#   PL: 4.96%
# Overall accuracy: 0.07%
#
# Finished processing cateogory in 10m21s
# Processing "bed" (2/39):
# Extracted 18000 entries from category bed
# Retained 18 countries
# Train: 16200 entries, test: 1800 entries.
# Done generating features and target
# PCA & standardization done. Keeping 460 features
# Done training model in 454.60s
# Done saving model, pca, and scaler to disk
# Category "bed"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('TH', 14.583333333333334), ('KR', 14.15929203539823), ('AU', 12.941176470588237), ('RU', 12.222222222222221), ('CZ', 10.185185185185185), ('SE', 9.89010989010989), ('FI', 9.278350515463918), ('HU', 7.017543859649122), ('GB', 6.956521739130435), ('BR', 6.796116504854369), ('NL', 5.9405940594059405), ('FR', 4.597701149425287), ('PH', 4.587155963302752), ('US', 4.301075268817205), ('IT', 4.166666666666666), ('DE', 3.8095238095238098), ('CA', 3.225806451612903), ('PL', 1.9230769230769231)]
#
# Scores greater than 5.56% (random chance):
#   TH: 14.58%
#   KR: 14.16%
#   AU: 12.94%
#   RU: 12.22%
#   CZ: 10.19%
#   SE: 9.89%
#   FI: 9.28%
#   HU: 7.02%
#   GB: 6.96%
#   BR: 6.80%
#   NL: 5.94%
# Overall accuracy: 0.08%
#
# Finished processing cateogory in 7m49s
# Processing "bench" (3/39):
# Extracted 19000 entries from category bench
# Retained 19 countries
# Train: 17100 entries, test: 1900 entries.
# Done generating features and target
# PCA & standardization done. Keeping 336 features
# /home/chris/.local/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/chris/.local/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Done training model in 764.84s
# Done saving model, pca, and scaler to disk
# Category "bench"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('JP', 13.541666666666666), ('KR', 13.26530612244898), ('PH', 12.195121951219512), ('NL', 12.037037037037036), ('SE', 10.377358490566039), ('FI', 8.51063829787234), ('US', 7.6923076923076925), ('TH', 7.608695652173914), ('RU', 7.000000000000001), ('IT', 6.481481481481481), ('PL', 6.0606060606060606), ('GB', 4.9504950495049505), ('CZ', 4.081632653061225), ('AU', 3.9215686274509802), ('FR', 3.125), ('CA', 2.586206896551724), ('HU', 2.127659574468085), ('DE', 2.083333333333333), ('BR', 1.0309278350515463)]
#
# Scores greater than 5.26% (random chance):
#   JP: 13.54%
#   KR: 13.27%
#   PH: 12.20%
#   NL: 12.04%
#   SE: 10.38%
#   FI: 8.51%
#   US: 7.69%
#   TH: 7.61%
#   RU: 7.00%
#   IT: 6.48%
#   PL: 6.06%
# Overall accuracy: 0.07%
#
# Finished processing cateogory in 12m58s
# Processing "bread" (4/39):
# Extracted 19000 entries from category bread
# Retained 19 countries
# Train: 17100 entries, test: 1900 entries.
# Done generating features and target
# PCA & standardization done. Keeping 469 features
# Done training model in 424.37s
# Done saving model, pca, and scaler to disk
# Category "bread"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('FR', 20.0), ('CA', 13.414634146341465), ('HU', 13.043478260869565), ('PH', 12.631578947368421), ('KR', 11.818181818181818), ('NL', 11.403508771929824), ('RU', 10.309278350515463), ('SA', 8.035714285714286), ('GB', 8.0), ('PL', 7.758620689655173), ('SE', 7.6923076923076925), ('DE', 7.547169811320755), ('AU', 7.526881720430108), ('CZ', 7.526881720430108), ('BR', 7.216494845360824), ('US', 5.825242718446602), ('TH', 5.555555555555555), ('IT', 4.301075268817205), ('FI', 0.9259259259259258)]
#
# Scores greater than 5.26% (random chance):
#   FR: 20.00%
#   CA: 13.41%
#   HU: 13.04%
#   PH: 12.63%
#   KR: 11.82%
#   NL: 11.40%
#   RU: 10.31%
#   SA: 8.04%
#   GB: 8.00%
#   PL: 7.76%
#   SE: 7.69%
#   DE: 7.55%
#   AU: 7.53%
#   CZ: 7.53%
#   BR: 7.22%
#   US: 5.83%
#   TH: 5.56%
# Overall accuracy: 0.09%
#
# Finished processing cateogory in 7m18s
# Processing "castle" (5/39):
# Extracted 19000 entries from category castle
# Retained 19 countries
# Train: 17100 entries, test: 1900 entries.
# Done generating features and target
# PCA & standardization done. Keeping 444 features
# Done training model in 360.08s
# Done saving model, pca, and scaler to disk
# Category "castle"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('KR', 18.34862385321101), ('SA', 13.084112149532709), ('TH', 9.917355371900827), ('NL', 9.523809523809524), ('PL', 9.523809523809524), ('PH', 8.411214953271028), ('BR', 8.256880733944955), ('DE', 8.0), ('CZ', 7.608695652173914), ('HU', 6.1946902654867255), ('FR', 5.681818181818182), ('RU', 5.376344086021505), ('GB', 4.807692307692308), ('SE', 4.395604395604396), ('FI', 4.395604395604396), ('AU', 3.488372093023256), ('CA', 3.125), ('US', 2.272727272727273), ('IT', 0.8620689655172413)]
#
# Scores greater than 5.26% (random chance):
#   KR: 18.35%
#   SA: 13.08%
#   TH: 9.92%
#   NL: 9.52%
#   PL: 9.52%
#   PH: 8.41%
#   BR: 8.26%
#   DE: 8.00%
#   CZ: 7.61%
#   HU: 6.19%
#   FR: 5.68%
#   RU: 5.38%
# Overall accuracy: 0.07%
#
# Finished processing cateogory in 6m14s
# Processing "cell phone" (6/39):
# Extracted 19000 entries from category cell phone
# Retained 19 countries
# Train: 17100 entries, test: 1900 entries.
# Done generating features and target
# PCA & standardization done. Keeping 351 features
# Done training model in 238.28s
# Done saving model, pca, and scaler to disk
# Category "cell phone"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('PL', 11.39240506329114), ('NL', 10.75268817204301), ('SE', 7.920792079207921), ('CZ', 7.6190476190476195), ('CA', 7.476635514018691), ('DE', 6.976744186046512), ('RU', 6.730769230769231), ('KR', 6.730769230769231), ('FI', 6.315789473684211), ('GB', 6.306306306306306), ('US', 5.1020408163265305), ('IT', 4.854368932038835), ('FR', 4.504504504504505), ('PH', 3.9603960396039604), ('SA', 3.9603960396039604), ('BR', 2.803738317757009), ('TH', 2.083333333333333), ('AU', 1.0752688172043012), ('HU', 0.9523809523809524)]
#
# Scores greater than 5.26% (random chance):
#   PL: 11.39%
#   NL: 10.75%
#   SE: 7.92%
#   CZ: 7.62%
#   CA: 7.48%
#   DE: 6.98%
#   RU: 6.73%
#   KR: 6.73%
#   FI: 6.32%
#   GB: 6.31%
# Overall accuracy: 0.06%
#
# Finished processing cateogory in 4m11s
# Processing "chair" (7/39):
# Extracted 31000 entries from category chair
# Retained 31 countries
# Train: 27900 entries, test: 3100 entries.
# Done generating features and target
# PCA & standardization done. Keeping 383 features
# Done training model in 855.67s
# Done saving model, pca, and scaler to disk
# Category "chair"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('SA', 12.244897959183673), ('TH', 12.068965517241379), ('KR', 11.475409836065573), ('JP', 8.771929824561402), ('RO', 7.777777777777778), ('TW', 7.777777777777778), ('AE', 6.451612903225806), ('AU', 6.382978723404255), ('CZ', 5.9405940594059405), ('ID', 5.825242718446602), ('PH', 5.555555555555555), ('IN', 5.4945054945054945), ('GB', 5.263157894736842), ('HR', 4.672897196261682), ('DE', 4.444444444444445), ('RU', 4.25531914893617), ('UA', 3.6036036036036037), ('MY', 3.260869565217391), ('CA', 3.125), ('IT', 3.061224489795918), ('SK', 3.0303030303030303), ('NL', 2.941176470588235), ('VN', 2.8846153846153846), ('BR', 2.459016393442623), ('FI', 2.2222222222222223), ('SE', 2.1052631578947367), ('PL', 2.0202020202020203), ('HU', 1.7241379310344827), ('NO', 1.1627906976744187), ('FR', 0.9803921568627451), ('US', 0.0)]
#
# Scores greater than 3.23% (random chance):
#   SA: 12.24%
#   TH: 12.07%
#   KR: 11.48%
#   JP: 8.77%
#   RO: 7.78%
#   TW: 7.78%
#   AE: 6.45%
#   AU: 6.38%
#   CZ: 5.94%
#   ID: 5.83%
#   PH: 5.56%
#   IN: 5.49%
#   GB: 5.26%
#   HR: 4.67%
#   DE: 4.44%
#   RU: 4.26%
#   UA: 3.60%
#   MY: 3.26%
# Overall accuracy: 0.05%
#
# Finished processing cateogory in 14m39s
# Processing "church" (8/39):
# Extracted 23000 entries from category church
# Retained 23 countries
# Train: 20700 entries, test: 2300 entries.
# Done generating features and target
# PCA & standardization done. Keeping 467 features
# Done training model in 533.23s
# Done saving model, pca, and scaler to disk
# Category "church"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('DE', 14.606741573033707), ('NL', 10.2803738317757), ('KR', 10.0), ('TH', 9.67741935483871), ('IN', 9.195402298850574), ('SE', 8.653846153846153), ('FI', 8.035714285714286), ('PH', 7.766990291262135), ('HU', 7.446808510638298), ('SA', 7.228915662650602), ('RO', 7.207207207207207), ('SK', 6.896551724137931), ('CZ', 6.451612903225806), ('US', 6.185567010309279), ('BR', 6.185567010309279), ('RU', 5.88235294117647), ('FR', 5.88235294117647), ('ID', 5.154639175257731), ('CA', 5.084745762711865), ('AU', 5.0), ('GB', 4.040404040404041), ('PL', 3.9603960396039604), ('IT', 3.0927835051546393)]
#
# Scores greater than 4.35% (random chance):
#   DE: 14.61%
#   NL: 10.28%
#   KR: 10.00%
#   TH: 9.68%
#   IN: 9.20%
#   SE: 8.65%
#   FI: 8.04%
#   PH: 7.77%
#   HU: 7.45%
#   SA: 7.23%
#   RO: 7.21%
#   SK: 6.90%
#   CZ: 6.45%
#   US: 6.19%
#   BR: 6.19%
#   RU: 5.88%
#   FR: 5.88%
#   ID: 5.15%
#   CA: 5.08%
#   AU: 5.00%
# Overall accuracy: 0.07%
#
# Finished processing cateogory in 9m11s
# Processing "coffee cup" (9/39):
# Extracted 26000 entries from category coffee cup
# Retained 26 countries
# Train: 23400 entries, test: 2600 entries.
# Done generating features and target
# PCA & standardization done. Keeping 524 features
# Done training model in 785.39s
# Done saving model, pca, and scaler to disk
# Category "coffee cup"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('JP', 10.891089108910892), ('TH', 10.0), ('KR', 9.375), ('IT', 8.98876404494382), ('TW', 7.777777777777778), ('SE', 7.368421052631578), ('PL', 7.079646017699115), ('AU', 6.185567010309279), ('PH', 5.4945054945054945), ('IN', 5.454545454545454), ('VN', 5.128205128205128), ('SA', 4.761904761904762), ('CZ', 4.672897196261682), ('US', 4.672897196261682), ('DE', 4.651162790697675), ('SK', 4.3478260869565215), ('GB', 4.25531914893617), ('RU', 4.2105263157894735), ('RO', 4.166666666666666), ('HU', 3.7383177570093453), ('ID', 3.7037037037037033), ('CA', 3.4482758620689653), ('BR', 3.0303030303030303), ('FR', 2.941176470588235), ('FI', 1.8867924528301887), ('NL', 0.0)]
#
# Scores greater than 3.85% (random chance):
#   JP: 10.89%
#   TH: 10.00%
#   KR: 9.38%
#   IT: 8.99%
#   TW: 7.78%
#   SE: 7.37%
#   PL: 7.08%
#   AU: 6.19%
#   PH: 5.49%
#   IN: 5.45%
#   VN: 5.13%
#   SA: 4.76%
#   CZ: 4.67%
#   US: 4.67%
#   DE: 4.65%
#   SK: 4.35%
#   GB: 4.26%
#   RU: 4.21%
#   RO: 4.17%
# Overall accuracy: 0.05%
#
# Finished processing cateogory in 13m27s
# Processing "crown" (10/39):
# Extracted 20000 entries from category crown
# Retained 20 countries
# Train: 18000 entries, test: 2000 entries.
# Done generating features and target
# PCA & standardization done. Keeping 439 features
# Done training model in 382.98s
# Done saving model, pca, and scaler to disk
# Category "crown"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('FI', 13.725490196078432), ('US', 9.89010989010989), ('PL', 8.16326530612245), ('FR', 7.920792079207921), ('ID', 7.608695652173914), ('NL', 7.368421052631578), ('KR', 7.339449541284404), ('TH', 7.142857142857142), ('AU', 6.730769230769231), ('GB', 6.41025641025641), ('CZ', 6.0), ('SA', 5.319148936170213), ('BR', 5.263157894736842), ('RU', 5.217391304347826), ('IT', 4.132231404958678), ('SE', 3.9215686274509802), ('PH', 3.75), ('DE', 3.7037037037037033), ('HU', 2.941176470588235), ('CA', 2.4390243902439024)]
#
# Scores greater than 5.00% (random chance):
#   FI: 13.73%
#   US: 9.89%
#   PL: 8.16%
#   FR: 7.92%
#   ID: 7.61%
#   NL: 7.37%
#   KR: 7.34%
#   TH: 7.14%
#   AU: 6.73%
#   GB: 6.41%
#   CZ: 6.00%
#   SA: 5.32%
#   BR: 5.26%
#   RU: 5.22%
# Overall accuracy: 0.06%
#
# Finished processing cateogory in 6m37s
# Processing "cruise ship" (11/39):
# Extracted 17000 entries from category cruise ship
# Retained 17 countries
# Train: 15300 entries, test: 1700 entries.
# Done generating features and target
# PCA & standardization done. Keeping 403 features
# Done training model in 303.99s
# Done saving model, pca, and scaler to disk
# Category "cruise ship"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('TH', 10.112359550561797), ('KR', 9.782608695652174), ('US', 8.737864077669903), ('FR', 8.24742268041237), ('SE', 8.19672131147541), ('RU', 7.608695652173914), ('CZ', 7.608695652173914), ('AU', 7.368421052631578), ('BR', 7.2727272727272725), ('IT', 6.666666666666667), ('PL', 6.122448979591836), ('FI', 5.952380952380952), ('CA', 5.9405940594059405), ('DE', 4.918032786885246), ('PH', 3.9603960396039604), ('GB', 2.857142857142857), ('NL', 1.8691588785046727)]
#
# Scores greater than 5.88% (random chance):
#   TH: 10.11%
#   KR: 9.78%
#   US: 8.74%
#   FR: 8.25%
#   SE: 8.20%
#   RU: 7.61%
#   CZ: 7.61%
#   AU: 7.37%
#   BR: 7.27%
#   IT: 6.67%
#   PL: 6.12%
#   FI: 5.95%
#   CA: 5.94%
# Overall accuracy: 0.07%
#
# Finished processing cateogory in 5m16s
# Processing "cup" (12/39):
# Extracted 21000 entries from category cup
# Retained 21 countries
# Train: 18900 entries, test: 2100 entries.
# Done generating features and target
# PCA & standardization done. Keeping 476 features
# Done training model in 432.56s
# Done saving model, pca, and scaler to disk
# Category "cup"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('BR', 14.545454545454545), ('RU', 12.280701754385964), ('US', 11.650485436893204), ('CA', 11.34020618556701), ('IT', 10.0), ('PH', 7.894736842105263), ('TH', 7.777777777777778), ('ID', 7.368421052631578), ('HU', 7.000000000000001), ('FR', 6.60377358490566), ('FI', 6.521739130434782), ('SE', 5.263157894736842), ('SA', 4.9504950495049505), ('AU', 4.301075268817205), ('KR', 4.301075268817205), ('PL', 3.8461538461538463), ('DE', 3.8095238095238098), ('CZ', 3.7037037037037033), ('IN', 3.3333333333333335), ('GB', 3.225806451612903), ('NL', 3.0927835051546393)]
#
# Scores greater than 4.76% (random chance):
#   BR: 14.55%
#   RU: 12.28%
#   US: 11.65%
#   CA: 11.34%
#   IT: 10.00%
#   PH: 7.89%
#   TH: 7.78%
#   ID: 7.37%
#   HU: 7.00%
#   FR: 6.60%
#   FI: 6.52%
#   SE: 5.26%
#   SA: 4.95%
# Overall accuracy: 0.07%
#
# Finished processing cateogory in 7m27s
# Processing "dishwasher" (13/39):
# Extracted 19000 entries from category dishwasher
# Retained 19 countries
# Train: 17100 entries, test: 1900 entries.
# Done generating features and target
# PCA & standardization done. Keeping 369 features
# Done training model in 284.08s
# Done saving model, pca, and scaler to disk
# Category "dishwasher"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('SK', 11.403508771929824), ('TH', 10.091743119266056), ('GB', 9.649122807017543), ('AU', 8.641975308641975), ('CA', 8.181818181818182), ('UA', 7.6190476190476195), ('FI', 6.896551724137931), ('FR', 6.666666666666667), ('RU', 5.208333333333334), ('PL', 4.9504950495049505), ('BR', 4.424778761061947), ('HU', 4.2105263157894735), ('CZ', 4.0), ('TR', 3.571428571428571), ('SE', 3.4482758620689653), ('NL', 3.3333333333333335), ('US', 3.1914893617021276), ('DE', 2.803738317757009), ('IT', 2.127659574468085)]
#
# Scores greater than 5.26% (random chance):
#   SK: 11.40%
#   TH: 10.09%
#   GB: 9.65%
#   AU: 8.64%
#   CA: 8.18%
#   UA: 7.62%
#   FI: 6.90%
#   FR: 6.67%
# Overall accuracy: 0.06%
#
# Finished processing cateogory in 4m58s
# Processing "dresser" (14/39):
# Extracted 14000 entries from category dresser
# Retained 14 countries
# Train: 12600 entries, test: 1400 entries.
# Done generating features and target
# PCA & standardization done. Keeping 332 features
# Done training model in 99.41s
# Done saving model, pca, and scaler to disk
# Category "dresser"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('PH', 16.19047619047619), ('AU', 11.688311688311687), ('FI', 10.909090909090908), ('US', 10.416666666666668), ('CA', 10.0), ('BR', 9.70873786407767), ('DE', 8.73015873015873), ('SE', 8.51063829787234), ('RU', 8.51063829787234), ('CZ', 8.333333333333332), ('IT', 7.920792079207921), ('PL', 5.0), ('GB', 4.545454545454546), ('FR', 3.4090909090909087)]
#
# Scores greater than 7.14% (random chance):
#   PH: 16.19%
#   AU: 11.69%
#   FI: 10.91%
#   US: 10.42%
#   CA: 10.00%
#   BR: 9.71%
#   DE: 8.73%
#   SE: 8.51%
#   RU: 8.51%
#   CZ: 8.33%
#   IT: 7.92%
# Overall accuracy: 0.09%
#
# Finished processing cateogory in 1m50s
# Processing "eye" (15/39):
# Extracted 21000 entries from category eye
# Retained 21 countries
# Train: 18900 entries, test: 2100 entries.
# Done generating features and target
# PCA & standardization done. Keeping 511 features
# Done training model in 497.96s
# Done saving model, pca, and scaler to disk
# Category "eye"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('KR', 11.11111111111111), ('TH', 9.523809523809524), ('HU', 9.345794392523365), ('NL', 7.766990291262135), ('SA', 7.142857142857142), ('ID', 6.862745098039216), ('FI', 6.8181818181818175), ('PL', 6.796116504854369), ('IN', 6.451612903225806), ('CZ', 6.422018348623854), ('IT', 6.122448979591836), ('CA', 5.747126436781609), ('BR', 5.617977528089887), ('FR', 5.154639175257731), ('DE', 3.8834951456310676), ('PH', 3.3333333333333335), ('RU', 3.278688524590164), ('GB', 3.225806451612903), ('SE', 3.0303030303030303), ('AU', 2.4390243902439024), ('US', 1.0101010101010102)]
#
# Scores greater than 4.76% (random chance):
#   KR: 11.11%
#   TH: 9.52%
#   HU: 9.35%
#   NL: 7.77%
#   SA: 7.14%
#   ID: 6.86%
#   FI: 6.82%
#   PL: 6.80%
#   IN: 6.45%
#   CZ: 6.42%
#   IT: 6.12%
#   CA: 5.75%
#   BR: 5.62%
#   FR: 5.15%
# Overall accuracy: 0.06%
#
# Finished processing cateogory in 8m33s
# Processing "face" (16/39):
# Extracted 24000 entries from category face
# Retained 24 countries
# Train: 21600 entries, test: 2400 entries.
# Done generating features and target
# PCA & standardization done. Keeping 514 features
# Done training model in 567.00s
# Done saving model, pca, and scaler to disk
# Category "face"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('CZ', 8.24742268041237), ('PL', 8.035714285714286), ('SK', 7.954545454545454), ('IN', 7.526881720430108), ('KR', 7.4074074074074066), ('RO', 7.291666666666667), ('NL', 6.730769230769231), ('ID', 6.481481481481481), ('FI', 6.25), ('TH', 5.9405940594059405), ('CA', 5.681818181818182), ('VN', 5.405405405405405), ('HU', 4.444444444444445), ('US', 4.444444444444445), ('GB', 4.385964912280701), ('BR', 4.0650406504065035), ('AU', 4.040404040404041), ('DE', 3.4482758620689653), ('PH', 3.260869565217391), ('FR', 3.260869565217391), ('RU', 2.941176470588235), ('SE', 2.7777777777777777), ('SA', 2.7522935779816518), ('IT', 2.0)]
#
# Scores greater than 4.17% (random chance):
#   CZ: 8.25%
#   PL: 8.04%
#   SK: 7.95%
#   IN: 7.53%
#   KR: 7.41%
#   RO: 7.29%
#   NL: 6.73%
#   ID: 6.48%
#   FI: 6.25%
#   TH: 5.94%
#   CA: 5.68%
#   VN: 5.41%
#   HU: 4.44%
#   US: 4.44%
#   GB: 4.39%
# Overall accuracy: 0.05%
#
# Finished processing cateogory in 9m45s
# Processing "fan" (17/39):
# Extracted 21000 entries from category fan
# Retained 21 countries
# Train: 18900 entries, test: 2100 entries.
# Done generating features and target
# PCA & standardization done. Keeping 608 features
# Done training model in 623.18s
# Done saving model, pca, and scaler to disk
# Category "fan"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('TH', 11.76470588235294), ('PH', 10.891089108910892), ('RU', 7.954545454545454), ('DE', 7.526881720430108), ('KR', 7.446808510638298), ('AU', 6.741573033707865), ('FR', 6.730769230769231), ('ID', 6.25), ('FI', 5.825242718446602), ('CZ', 5.46875), ('GB', 5.263157894736842), ('CA', 5.208333333333334), ('SA', 4.807692307692308), ('BR', 4.597701149425287), ('US', 4.545454545454546), ('IT', 4.3478260869565215), ('TW', 4.166666666666666), ('NL', 3.9603960396039604), ('SE', 2.8301886792452833), ('HU', 2.197802197802198), ('PL', 0.0)]
#
# Scores greater than 4.76% (random chance):
#   TH: 11.76%
#   PH: 10.89%
#   RU: 7.95%
#   DE: 7.53%
#   KR: 7.45%
#   AU: 6.74%
#   FR: 6.73%
#   ID: 6.25%
#   FI: 5.83%
#   CZ: 5.47%
#   GB: 5.26%
#   CA: 5.21%
#   SA: 4.81%
# Overall accuracy: 0.06%
#
# Finished processing cateogory in 10m39s
# Processing "fire hydrant" (18/39):
# Extracted 15000 entries from category fire hydrant
# Retained 15 countries
# Train: 13500 entries, test: 1500 entries.
# Done generating features and target
# PCA & standardization done. Keeping 490 features
# Done training model in 222.38s
# Done saving model, pca, and scaler to disk
# Category "fire hydrant"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('BR', 15.463917525773196), ('HU', 13.20754716981132), ('SE', 11.650485436893204), ('CZ', 11.504424778761061), ('GB', 9.523809523809524), ('FI', 9.375), ('PH', 8.24742268041237), ('AU', 7.920792079207921), ('DE', 6.896551724137931), ('US', 6.862745098039216), ('FR', 5.3097345132743365), ('CA', 4.587155963302752), ('PL', 4.25531914893617), ('RU', 4.081632653061225), ('IT', 4.0)]
#
# Scores greater than 6.67% (random chance):
#   BR: 15.46%
#   HU: 13.21%
#   SE: 11.65%
#   CZ: 11.50%
#   GB: 9.52%
#   FI: 9.38%
#   PH: 8.25%
#   AU: 7.92%
#   DE: 6.90%
#   US: 6.86%
# Overall accuracy: 0.08%
#
# Finished processing cateogory in 3m54s
# Processing "fish" (19/39):
# Extracted 22000 entries from category fish
# Retained 22 countries
# Train: 19800 entries, test: 2200 entries.
# Done generating features and target
# PCA & standardization done. Keeping 503 features
# Done training model in 493.98s
# Done saving model, pca, and scaler to disk
# Category "fish"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('RU', 20.930232558139537), ('PH', 12.871287128712872), ('TW', 11.76470588235294), ('KR', 10.576923076923077), ('BR', 10.309278350515463), ('US', 7.526881720430108), ('ID', 6.862745098039216), ('CZ', 6.5420560747663545), ('PL', 5.660377358490567), ('TH', 5.154639175257731), ('VN', 4.9504950495049505), ('FI', 4.854368932038835), ('SE', 4.716981132075472), ('GB', 4.672897196261682), ('SA', 3.571428571428571), ('DE', 3.296703296703297), ('AU', 2.941176470588235), ('HU', 2.727272727272727), ('CA', 2.4390243902439024), ('NL', 2.247191011235955), ('FR', 1.9047619047619049), ('IT', 1.0309278350515463)]
#
# Scores greater than 4.55% (random chance):
#   RU: 20.93%
#   PH: 12.87%
#   TW: 11.76%
#   KR: 10.58%
#   BR: 10.31%
#   US: 7.53%
#   ID: 6.86%
#   CZ: 6.54%
#   PL: 5.66%
#   TH: 5.15%
#   VN: 4.95%
#   FI: 4.85%
#   SE: 4.72%
#   GB: 4.67%
# Overall accuracy: 0.06%
#
# Finished processing cateogory in 8m29s
# Processing "hammer" (20/39):
# Extracted 19000 entries from category hammer
# Retained 19 countries
# Train: 17100 entries, test: 1900 entries.
# Done generating features and target
# PCA & standardization done. Keeping 500 features
# Done training model in 406.49s
# Done saving model, pca, and scaler to disk
# Category "hammer"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('CA', 11.458333333333332), ('KR', 9.649122807017543), ('US', 9.375), ('PH', 8.60215053763441), ('CZ', 8.181818181818182), ('TH', 7.8431372549019605), ('NL', 7.6923076923076925), ('RU', 7.000000000000001), ('IT', 6.25), ('HU', 6.122448979591836), ('SE', 5.617977528089887), ('GB', 5.5045871559633035), ('BR', 5.3097345132743365), ('FI', 4.9504950495049505), ('SA', 4.123711340206185), ('DE', 4.040404040404041), ('PL', 3.9215686274509802), ('AU', 3.6585365853658534), ('FR', 3.0303030303030303)]
#
# Scores greater than 5.26% (random chance):
#   CA: 11.46%
#   KR: 9.65%
#   US: 9.38%
#   PH: 8.60%
#   CZ: 8.18%
#   TH: 7.84%
#   NL: 7.69%
#   RU: 7.00%
#   IT: 6.25%
#   HU: 6.12%
#   SE: 5.62%
#   GB: 5.50%
#   BR: 5.31%
# Overall accuracy: 0.06%
#
# Finished processing cateogory in 6m59s
# Processing "hat" (21/39):
# Extracted 30000 entries from category hat
# Retained 30 countries
# Train: 27000 entries, test: 3000 entries.
# Done generating features and target
# PCA & standardization done. Keeping 407 features
# Done training model in 806.67s
# Done saving model, pca, and scaler to disk
# Category "hat"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('US', 9.375), ('ID', 8.108108108108109), ('IT', 6.557377049180328), ('JP', 6.422018348623854), ('GB', 5.617977528089887), ('CA', 5.263157894736842), ('VN', 4.9504950495049505), ('NO', 4.9504950495049505), ('DE', 4.878048780487805), ('FR', 4.504504504504505), ('SA', 4.301075268817205), ('NL', 3.8095238095238098), ('TH', 3.7383177570093453), ('RO', 3.669724770642202), ('AU', 2.9702970297029703), ('KR', 2.8846153846153846), ('FI', 2.7777777777777777), ('TW', 2.4096385542168677), ('SE', 2.3529411764705883), ('RU', 2.197802197802198), ('IN', 2.127659574468085), ('MY', 2.0202020202020203), ('SK', 1.9047619047619049), ('HU', 1.8867924528301887), ('AE', 1.8181818181818181), ('PL', 1.2048192771084338), ('CZ', 1.0), ('BR', 0.9708737864077669), ('UA', 0.9433962264150944), ('PH', 0.0)]
#
# Scores greater than 3.33% (random chance):
#   US: 9.38%
#   ID: 8.11%
#   IT: 6.56%
#   JP: 6.42%
#   GB: 5.62%
#   CA: 5.26%
#   VN: 4.95%
#   NO: 4.95%
#   DE: 4.88%
#   FR: 4.50%
#   SA: 4.30%
#   NL: 3.81%
#   TH: 3.74%
#   RO: 3.67%
# Overall accuracy: 0.04%
#
# Finished processing cateogory in 13m49s
# Processing "helicopter" (22/39):
# Extracted 23000 entries from category helicopter
# Retained 23 countries
# Train: 20700 entries, test: 2300 entries.
# Done generating features and target
# PCA & standardization done. Keeping 526 features
# Done training model in 569.07s
# Done saving model, pca, and scaler to disk
# Category "helicopter"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('ID', 15.09433962264151), ('TH', 13.793103448275861), ('BR', 9.278350515463918), ('SK', 8.60215053763441), ('FI', 8.130081300813007), ('CA', 7.2727272727272725), ('US', 6.796116504854369), ('IN', 6.666666666666667), ('SE', 6.097560975609756), ('SA', 5.825242718446602), ('AU', 4.854368932038835), ('RU', 4.716981132075472), ('CZ', 4.672897196261682), ('GB', 4.3478260869565215), ('KR', 4.301075268817205), ('FR', 4.301075268817205), ('DE', 4.123711340206185), ('NL', 4.0650406504065035), ('PL', 3.7037037037037033), ('RO', 3.7037037037037033), ('PH', 3.125), ('IT', 2.857142857142857), ('HU', 1.1494252873563218)]
#
# Scores greater than 4.35% (random chance):
#   ID: 15.09%
#   TH: 13.79%
#   BR: 9.28%
#   SK: 8.60%
#   FI: 8.13%
#   CA: 7.27%
#   US: 6.80%
#   IN: 6.67%
#   SE: 6.10%
#   SA: 5.83%
#   AU: 4.85%
#   RU: 4.72%
#   CZ: 4.67%
# Overall accuracy: 0.06%
#
# Finished processing cateogory in 9m47s
# Processing "ice cream" (23/39):
# Extracted 21000 entries from category ice cream
# Retained 21 countries
# Train: 18900 entries, test: 2100 entries.
# Done generating features and target
# PCA & standardization done. Keeping 457 features
# Done training model in 406.16s
# Done saving model, pca, and scaler to disk
# Category "ice cream"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('IN', 14.545454545454545), ('IT', 12.631578947368421), ('US', 10.869565217391305), ('HU', 10.75268817204301), ('CZ', 9.523809523809524), ('SE', 9.01639344262295), ('KR', 8.928571428571429), ('TH', 8.823529411764707), ('CA', 7.8431372549019605), ('BR', 7.2727272727272725), ('GB', 7.07070707070707), ('FI', 6.9306930693069315), ('AU', 6.185567010309279), ('ID', 5.660377358490567), ('DE', 5.376344086021505), ('NL', 4.672897196261682), ('RU', 4.444444444444445), ('PH', 2.3529411764705883), ('PL', 2.197802197802198), ('FR', 2.197802197802198), ('SA', 1.0309278350515463)]
#
# Scores greater than 4.76% (random chance):
#   IN: 14.55%
#   IT: 12.63%
#   US: 10.87%
#   HU: 10.75%
#   CZ: 9.52%
#   SE: 9.02%
#   KR: 8.93%
#   TH: 8.82%
#   CA: 7.84%
#   BR: 7.27%
#   GB: 7.07%
#   FI: 6.93%
#   AU: 6.19%
#   ID: 5.66%
#   DE: 5.38%
# Overall accuracy: 0.07%
#
# Finished processing cateogory in 7m0s
# Processing "lantern" (24/39):
# Extracted 22000 entries from category lantern
# Retained 22 countries
# Train: 19800 entries, test: 2200 entries.
# Done generating features and target
# PCA & standardization done. Keeping 561 features
# Done training model in 576.67s
# Done saving model, pca, and scaler to disk
# Category "lantern"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('BR', 34.234234234234236), ('PL', 14.678899082568808), ('HU', 11.956521739130435), ('SA', 10.1010101010101), ('JP', 9.523809523809524), ('KR', 9.090909090909092), ('NL', 8.24742268041237), ('IN', 7.766990291262135), ('DE', 7.0588235294117645), ('RU', 6.8181818181818175), ('CZ', 6.779661016949152), ('IT', 5.813953488372093), ('US', 5.769230769230769), ('GB', 5.154639175257731), ('TH', 5.154639175257731), ('ID', 4.9504950495049505), ('SE', 4.807692307692308), ('FR', 4.395604395604396), ('FI', 3.361344537815126), ('AU', 2.857142857142857), ('PH', 2.7777777777777777), ('CA', 1.9417475728155338)]
#
# Scores greater than 4.55% (random chance):
#   BR: 34.23%
#   PL: 14.68%
#   HU: 11.96%
#   SA: 10.10%
#   JP: 9.52%
#   KR: 9.09%
#   NL: 8.25%
#   IN: 7.77%
#   DE: 7.06%
#   RU: 6.82%
#   CZ: 6.78%
#   IT: 5.81%
#   US: 5.77%
#   GB: 5.15%
#   TH: 5.15%
#   ID: 4.95%
#   SE: 4.81%
# Overall accuracy: 0.08%
#
# Finished processing cateogory in 9m53s
# Processing "passport" (25/39):
# Extracted 22000 entries from category passport
# Retained 22 countries
# Train: 19800 entries, test: 2200 entries.
# Done generating features and target
# PCA & standardization done. Keeping 434 features
# Done training model in 436.72s
# Done saving model, pca, and scaler to disk
# Category "passport"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('FI', 9.782608695652174), ('SA', 8.547008547008547), ('BR', 7.000000000000001), ('IN', 7.000000000000001), ('DE', 6.60377358490566), ('CA', 6.451612903225806), ('KR', 6.382978723404255), ('FR', 5.714285714285714), ('TH', 5.607476635514018), ('RU', 5.5045871559633035), ('NL', 5.05050505050505), ('PL', 5.0), ('RO', 4.761904761904762), ('IT', 4.62962962962963), ('GB', 4.545454545454546), ('ID', 4.504504504504505), ('US', 4.301075268817205), ('PH', 4.2105263157894735), ('AU', 4.123711340206185), ('HU', 3.8095238095238098), ('CZ', 3.296703296703297), ('SE', 2.380952380952381)]
#
# Scores greater than 4.55% (random chance):
#   FI: 9.78%
#   SA: 8.55%
#   BR: 7.00%
#   IN: 7.00%
#   DE: 6.60%
#   CA: 6.45%
#   KR: 6.38%
#   FR: 5.71%
#   TH: 5.61%
#   RU: 5.50%
#   NL: 5.05%
#   PL: 5.00%
#   RO: 4.76%
#   IT: 4.63%
# Overall accuracy: 0.05%
#
# Finished processing cateogory in 7m33s
# Processing "pickup truck" (26/39):
# Extracted 19000 entries from category pickup truck
# Retained 19 countries
# Train: 17100 entries, test: 1900 entries.
# Done generating features and target
# PCA & standardization done. Keeping 449 features
# Done training model in 331.66s
# Done saving model, pca, and scaler to disk
# Category "pickup truck"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('KR', 16.363636363636363), ('US', 12.264150943396226), ('CZ', 11.76470588235294), ('SE', 11.458333333333332), ('FI', 11.11111111111111), ('AU', 10.465116279069768), ('DE', 10.0), ('ID', 9.900990099009901), ('SA', 9.523809523809524), ('RU', 7.228915662650602), ('BR', 7.079646017699115), ('PH', 7.000000000000001), ('CA', 6.0), ('NL', 5.747126436781609), ('TH', 5.208333333333334), ('FR', 4.716981132075472), ('PL', 4.504504504504505), ('IT', 3.5398230088495577), ('GB', 3.488372093023256)]
#
# Scores greater than 5.26% (random chance):
#   KR: 16.36%
#   US: 12.26%
#   CZ: 11.76%
#   SE: 11.46%
#   FI: 11.11%
#   AU: 10.47%
#   DE: 10.00%
#   ID: 9.90%
#   SA: 9.52%
#   RU: 7.23%
#   BR: 7.08%
#   PH: 7.00%
#   CA: 6.00%
#   NL: 5.75%
# Overall accuracy: 0.08%
#
# Finished processing cateogory in 5m45s
# Processing "pillow" (27/39):
# Extracted 20000 entries from category pillow
# Retained 20 countries
# Train: 18000 entries, test: 2000 entries.
# Done generating features and target
# PCA & standardization done. Keeping 363 features
# Done training model in 335.99s
# Done saving model, pca, and scaler to disk
# Category "pillow"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('KR', 9.25925925925926), ('PL', 8.98876404494382), ('IT', 7.207207207207207), ('BR', 6.896551724137931), ('ID', 6.666666666666667), ('GB', 6.315789473684211), ('CA', 5.405405405405405), ('TH', 5.357142857142857), ('HU', 5.154639175257731), ('SE', 5.063291139240507), ('SA', 5.05050505050505), ('AU', 4.62962962962963), ('NL', 4.081632653061225), ('DE', 3.9215686274509802), ('FR', 3.6363636363636362), ('US', 3.6036036036036037), ('RU', 3.3333333333333335), ('PH', 3.0303030303030303), ('FI', 3.0303030303030303), ('CZ', 0.9523809523809524)]
#
# Scores greater than 5.00% (random chance):
#   KR: 9.26%
#   PL: 8.99%
#   IT: 7.21%
#   BR: 6.90%
#   ID: 6.67%
#   GB: 6.32%
#   CA: 5.41%
#   TH: 5.36%
#   HU: 5.15%
#   SE: 5.06%
#   SA: 5.05%
# Overall accuracy: 0.05%
#
# Finished processing cateogory in 5m48s
# Processing "power outlet" (28/39):
# Extracted 18000 entries from category power outlet
# Retained 18 countries
# Train: 16200 entries, test: 1800 entries.
# Done generating features and target
# PCA & standardization done. Keeping 417 features
# Done training model in 310.80s
# Done saving model, pca, and scaler to disk
# Category "power outlet"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('GB', 25.555555555555554), ('AU', 18.556701030927837), ('KR', 14.423076923076922), ('RU', 12.711864406779661), ('PH', 11.224489795918368), ('FR', 10.309278350515463), ('BR', 9.523809523809524), ('NL', 9.090909090909092), ('SE', 8.88888888888889), ('DE', 8.653846153846153), ('CZ', 8.60215053763441), ('US', 8.256880733944955), ('CA', 8.24742268041237), ('SA', 8.24742268041237), ('FI', 6.741573033707865), ('IT', 4.504504504504505), ('HU', 4.040404040404041), ('PL', 2.1739130434782608)]
#
# Scores greater than 5.56% (random chance):
#   GB: 25.56%
#   AU: 18.56%
#   KR: 14.42%
#   RU: 12.71%
#   PH: 11.22%
#   FR: 10.31%
#   BR: 9.52%
#   NL: 9.09%
#   SE: 8.89%
#   DE: 8.65%
#   CZ: 8.60%
#   US: 8.26%
#   CA: 8.25%
#   SA: 8.25%
#   FI: 6.74%
# Overall accuracy: 0.10%
#
# Finished processing cateogory in 5m24s
# Processing "sailboat" (29/39):
# Extracted 20000 entries from category sailboat
# Retained 20 countries
# Train: 18000 entries, test: 2000 entries.
# Done generating features and target
# PCA & standardization done. Keeping 480 features
# Done training model in 410.09s
# Done saving model, pca, and scaler to disk
# Category "sailboat"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('DE', 12.264150943396226), ('GB', 12.0), ('SA', 11.0), ('AU', 10.679611650485436), ('RU', 9.900990099009901), ('ID', 8.737864077669903), ('FI', 8.620689655172415), ('FR', 8.235294117647058), ('NL', 8.035714285714286), ('KR', 7.547169811320755), ('TH', 7.446808510638298), ('PH', 7.368421052631578), ('PL', 5.88235294117647), ('BR', 5.88235294117647), ('CZ', 5.154639175257731), ('CA', 5.063291139240507), ('HU', 4.9504950495049505), ('SE', 3.4482758620689653), ('IT', 1.9801980198019802), ('US', 0.9090909090909091)]
#
# Scores greater than 5.00% (random chance):
#   DE: 12.26%
#   GB: 12.00%
#   SA: 11.00%
#   AU: 10.68%
#   RU: 9.90%
#   ID: 8.74%
#   FI: 8.62%
#   FR: 8.24%
#   NL: 8.04%
#   KR: 7.55%
#   TH: 7.45%
#   PH: 7.37%
#   PL: 5.88%
#   BR: 5.88%
#   CZ: 5.15%
#   CA: 5.06%
# Overall accuracy: 0.07%
#
# Finished processing cateogory in 7m3s
# Processing "sandwich" (30/39):
# Extracted 20000 entries from category sandwich
# Retained 20 countries
# Train: 18000 entries, test: 2000 entries.
# Done generating features and target
# PCA & standardization done. Keeping 457 features
# Done training model in 409.43s
# Done saving model, pca, and scaler to disk
# Category "sandwich"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('TH', 18.29268292682927), ('FR', 13.580246913580247), ('HU', 11.881188118811881), ('AU', 10.185185185185185), ('CA', 9.0), ('ID', 8.928571428571429), ('PH', 8.403361344537815), ('FI', 7.6923076923076925), ('CZ', 6.896551724137931), ('IT', 6.862745098039216), ('SA', 6.593406593406594), ('RU', 6.185567010309279), ('BR', 5.982905982905983), ('SE', 5.813953488372093), ('US', 5.454545454545454), ('GB', 5.208333333333334), ('KR', 5.1020408163265305), ('NL', 4.901960784313726), ('PL', 4.395604395604396), ('DE', 3.4482758620689653)]
#
# Scores greater than 5.00% (random chance):
#   TH: 18.29%
#   FR: 13.58%
#   HU: 11.88%
#   AU: 10.19%
#   CA: 9.00%
#   ID: 8.93%
#   PH: 8.40%
#   FI: 7.69%
#   CZ: 6.90%
#   IT: 6.86%
#   SA: 6.59%
#   RU: 6.19%
#   BR: 5.98%
#   SE: 5.81%
#   US: 5.45%
#   GB: 5.21%
#   KR: 5.10%
# Overall accuracy: 0.08%
#
# Finished processing cateogory in 7m4s
# Processing "snowman" (31/39):
# Extracted 44000 entries from category snowman
# Retained 44 countries
# Train: 39600 entries, test: 4400 entries.
# Done generating features and target
# PCA & standardization done. Keeping 554 features
# Done training model in 2270.28s
# Done saving model, pca, and scaler to disk
# Category "snowman"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('MY', 7.777777777777778), ('JP', 7.339449541284404), ('SK', 7.142857142857142), ('DK', 6.666666666666667), ('FI', 5.88235294117647), ('KR', 5.454545454545454), ('ID', 4.587155963302752), ('BE', 4.3478260869565215), ('NZ', 4.25531914893617), ('TH', 4.123711340206185), ('IN', 3.8834951456310676), ('PL', 3.6585365853658534), ('CA', 3.571428571428571), ('BG', 3.571428571428571), ('UA', 3.4482758620689653), ('AT', 3.260869565217391), ('AE', 3.061224489795918), ('CH', 3.0), ('TW', 2.9702970297029703), ('US', 2.941176470588235), ('HU', 2.912621359223301), ('TR', 2.8846153846153846), ('RU', 2.7027027027027026), ('AU', 2.6785714285714284), ('SE', 2.380952380952381), ('ES', 2.3529411764705883), ('MX', 2.272727272727273), ('RS', 2.197802197802198), ('BR', 2.1052631578947367), ('VN', 2.0618556701030926), ('SA', 2.0202020202020203), ('HR', 1.8691588785046727), ('GB', 1.7699115044247788), ('IE', 1.7699115044247788), ('HK', 1.1764705882352942), ('PH', 1.0752688172043012), ('FR', 1.0638297872340425), ('NO', 1.0309278350515463), ('RO', 1.0309278350515463), ('DE', 1.0101010101010102), ('CZ', 0.9900990099009901), ('IT', 0.819672131147541), ('PT', 0.0), ('NL', 0.0)]
#
# Scores greater than 2.27% (random chance):
#   MY: 7.78%
#   JP: 7.34%
#   SK: 7.14%
#   DK: 6.67%
#   FI: 5.88%
#   KR: 5.45%
#   ID: 4.59%
#   BE: 4.35%
#   NZ: 4.26%
#   TH: 4.12%
#   IN: 3.88%
#   PL: 3.66%
#   CA: 3.57%
#   BG: 3.57%
#   UA: 3.45%
#   AT: 3.26%
#   AE: 3.06%
#   CH: 3.00%
#   TW: 2.97%
#   US: 2.94%
#   HU: 2.91%
#   TR: 2.88%
#   RU: 2.70%
#   AU: 2.68%
#   SE: 2.38%
#   ES: 2.35%
# Overall accuracy: 0.03%
#
# Finished processing cateogory in 38m28s
# Processing "star" (32/39):
# Extracted 21000 entries from category star
# Retained 21 countries
# Train: 18900 entries, test: 2100 entries.
# Done generating features and target
# PCA & standardization done. Keeping 623 features
# Done training model in 659.52s
# Done saving model, pca, and scaler to disk
# Category "star"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('SA', 10.185185185185185), ('PH', 10.0), ('KR', 8.88888888888889), ('CZ', 8.547008547008547), ('US', 8.421052631578947), ('PL', 8.13953488372093), ('FI', 7.8431372549019605), ('SE', 7.6923076923076925), ('TH', 7.368421052631578), ('GB', 6.122448979591836), ('DE', 5.813953488372093), ('HU', 5.376344086021505), ('IT', 5.3097345132743365), ('AU', 4.761904761904762), ('VN', 4.761904761904762), ('ID', 4.672897196261682), ('CA', 4.2105263157894735), ('RU', 4.0), ('BR', 2.8301886792452833), ('NL', 2.7027027027027026), ('FR', 1.0309278350515463)]
#
# Scores greater than 4.76% (random chance):
#   SA: 10.19%
#   PH: 10.00%
#   KR: 8.89%
#   CZ: 8.55%
#   US: 8.42%
#   PL: 8.14%
#   FI: 7.84%
#   SE: 7.69%
#   TH: 7.37%
#   GB: 6.12%
#   DE: 5.81%
#   HU: 5.38%
#   IT: 5.31%
# Overall accuracy: 0.06%
#
# Finished processing cateogory in 11m39s
# Processing "strawberry" (33/39):
# Extracted 20000 entries from category strawberry
# Retained 20 countries
# Train: 18000 entries, test: 2000 entries.
# Done generating features and target
# PCA & standardization done. Keeping 539 features
# Done training model in 476.63s
# Done saving model, pca, and scaler to disk
# Category "strawberry"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('TH', 14.15929203539823), ('KR', 8.51063829787234), ('DE', 8.333333333333332), ('ID', 8.108108108108109), ('US', 8.080808080808081), ('NL', 7.894736842105263), ('HU', 7.017543859649122), ('RU', 6.976744186046512), ('IT', 6.896551724137931), ('SA', 6.315789473684211), ('FR', 5.617977528089887), ('BR', 5.0), ('PH', 4.854368932038835), ('CA', 4.854368932038835), ('AU', 4.807692307692308), ('GB', 4.597701149425287), ('FI', 4.0), ('PL', 3.6585365853658534), ('SE', 3.5398230088495577), ('CZ', 2.0408163265306123)]
#
# Scores greater than 5.00% (random chance):
#   TH: 14.16%
#   KR: 8.51%
#   DE: 8.33%
#   ID: 8.11%
#   US: 8.08%
#   NL: 7.89%
#   HU: 7.02%
#   RU: 6.98%
#   IT: 6.90%
#   SA: 6.32%
#   FR: 5.62%
# Overall accuracy: 0.06%
#
# Finished processing cateogory in 8m14s
# Processing "suitcase" (34/39):
# Extracted 18000 entries from category suitcase
# Retained 18 countries
# Train: 16200 entries, test: 1800 entries.
# Done generating features and target
# PCA & standardization done. Keeping 330 features
# Done training model in 265.51s
# Done saving model, pca, and scaler to disk
# Category "suitcase"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('IN', 13.48314606741573), ('SE', 9.90990990990991), ('KR', 8.91089108910891), ('CZ', 8.045977011494253), ('PH', 7.894736842105263), ('GB', 7.446808510638298), ('US', 6.60377358490566), ('CA', 6.122448979591836), ('AU', 5.769230769230769), ('RU', 5.660377358490567), ('DE', 5.660377358490567), ('FR', 5.617977528089887), ('PL', 4.901960784313726), ('FI', 4.62962962962963), ('NL', 4.301075268817205), ('HU', 2.1739130434782608), ('IT', 2.127659574468085), ('BR', 1.8867924528301887)]
#
# Scores greater than 5.56% (random chance):
#   IN: 13.48%
#   SE: 9.91%
#   KR: 8.91%
#   CZ: 8.05%
#   PH: 7.89%
#   GB: 7.45%
#   US: 6.60%
#   CA: 6.12%
#   AU: 5.77%
#   RU: 5.66%
#   DE: 5.66%
#   FR: 5.62%
# Overall accuracy: 0.06%
#
# Finished processing cateogory in 4m38s
# Processing "table" (35/39):
# Extracted 20000 entries from category table
# Retained 20 countries
# Train: 18000 entries, test: 2000 entries.
# Done generating features and target
# PCA & standardization done. Keeping 380 features
# Done training model in 445.68s
# Done saving model, pca, and scaler to disk
# Category "table"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('KR', 17.894736842105264), ('PL', 13.333333333333334), ('TH', 11.403508771929824), ('PH', 9.523809523809524), ('CZ', 8.333333333333332), ('FR', 7.368421052631578), ('BR', 5.681818181818182), ('RU', 5.376344086021505), ('DE', 4.878048780487805), ('SA', 4.854368932038835), ('AU', 4.716981132075472), ('ID', 4.62962962962963), ('NL', 4.3478260869565215), ('IT', 4.040404040404041), ('HU', 4.0), ('CA', 4.0), ('GB', 3.571428571428571), ('FI', 3.1578947368421053), ('US', 2.0), ('SE', 0.9615384615384616)]
#
# Scores greater than 5.00% (random chance):
#   KR: 17.89%
#   PL: 13.33%
#   TH: 11.40%
#   PH: 9.52%
#   CZ: 8.33%
#   FR: 7.37%
#   BR: 5.68%
#   RU: 5.38%
# Overall accuracy: 0.06%
#
# Finished processing cateogory in 7m40s
# Processing "telephone" (36/39):
# Extracted 19000 entries from category telephone
# Retained 19 countries
# Train: 17100 entries, test: 1900 entries.
# Done generating features and target
# PCA & standardization done. Keeping 524 features
# Done training model in 432.36s
# Done saving model, pca, and scaler to disk
# Category "telephone"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('HU', 14.606741573033707), ('SE', 11.235955056179774), ('CZ', 11.0), ('FI', 10.619469026548673), ('SA', 10.576923076923077), ('KR', 9.90990990990991), ('BR', 9.345794392523365), ('DE', 9.278350515463918), ('GB', 8.823529411764707), ('PH', 8.60215053763441), ('US', 7.6923076923076925), ('CA', 7.6923076923076925), ('PL', 7.216494845360824), ('AU', 6.730769230769231), ('NL', 5.825242718446602), ('FR', 5.813953488372093), ('TH', 5.555555555555555), ('IT', 3.8095238095238098), ('RU', 3.0927835051546393)]
#
# Scores greater than 5.26% (random chance):
#   HU: 14.61%
#   SE: 11.24%
#   CZ: 11.00%
#   FI: 10.62%
#   SA: 10.58%
#   KR: 9.91%
#   BR: 9.35%
#   DE: 9.28%
#   GB: 8.82%
#   PH: 8.60%
#   US: 7.69%
#   CA: 7.69%
#   PL: 7.22%
#   AU: 6.73%
#   NL: 5.83%
#   FR: 5.81%
#   TH: 5.56%
# Overall accuracy: 0.08%
#
# Finished processing cateogory in 7m26s
# Processing "traffic light" (37/39):
# Extracted 20000 entries from category traffic light
# Retained 20 countries
# Train: 18000 entries, test: 2000 entries.
# Done generating features and target
# PCA & standardization done. Keeping 352 features
# Done training model in 295.99s
# Done saving model, pca, and scaler to disk
# Category "traffic light"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('KR', 20.0), ('US', 11.214953271028037), ('PL', 9.649122807017543), ('AU', 7.526881720430108), ('DE', 7.446808510638298), ('SE', 7.291666666666667), ('CA', 7.142857142857142), ('HU', 6.862745098039216), ('BR', 6.862745098039216), ('TH', 6.122448979591836), ('IT', 5.769230769230769), ('SA', 5.714285714285714), ('RU', 5.208333333333334), ('ID', 4.854368932038835), ('NL', 4.62962962962963), ('PH', 4.3478260869565215), ('CZ', 4.2105263157894735), ('FI', 4.166666666666666), ('GB', 2.0), ('FR', 1.9607843137254901)]
#
# Scores greater than 5.00% (random chance):
#   KR: 20.00%
#   US: 11.21%
#   PL: 9.65%
#   AU: 7.53%
#   DE: 7.45%
#   SE: 7.29%
#   CA: 7.14%
#   HU: 6.86%
#   BR: 6.86%
#   TH: 6.12%
#   IT: 5.77%
#   SA: 5.71%
#   RU: 5.21%
# Overall accuracy: 0.07%
#
# Finished processing cateogory in 5m10s
# Processing "watermelon" (38/39):
# Extracted 23000 entries from category watermelon
# Retained 23 countries
# Train: 20700 entries, test: 2300 entries.
# Done generating features and target
# PCA & standardization done. Keeping 545 features
# Done training model in 685.70s
# Done saving model, pca, and scaler to disk
# Category "watermelon"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('TH', 9.174311926605505), ('DE', 9.0), ('KR', 8.333333333333332), ('IN', 8.24742268041237), ('HU', 7.6923076923076925), ('CZ', 7.216494845360824), ('FR', 6.741573033707865), ('AU', 6.315789473684211), ('IT', 5.9405940594059405), ('CA', 4.9504950495049505), ('PH', 4.901960784313726), ('PL', 4.761904761904762), ('SA', 4.672897196261682), ('RU', 4.651162790697675), ('US', 4.62962962962963), ('RO', 4.597701149425287), ('NL', 4.545454545454546), ('ID', 4.545454545454546), ('FI', 3.5398230088495577), ('BR', 3.1914893617021276), ('SE', 2.0), ('GB', 1.9417475728155338), ('SK', 1.0204081632653061)]
#
# Scores greater than 4.35% (random chance):
#   TH: 9.17%
#   DE: 9.00%
#   KR: 8.33%
#   IN: 8.25%
#   HU: 7.69%
#   CZ: 7.22%
#   FR: 6.74%
#   AU: 6.32%
#   IT: 5.94%
#   CA: 4.95%
#   PH: 4.90%
#   PL: 4.76%
#   SA: 4.67%
#   RU: 4.65%
#   US: 4.63%
#   RO: 4.60%
#   NL: 4.55%
#   ID: 4.55%
# Overall accuracy: 0.05%
#
# Finished processing cateogory in 11m43s
# Processing "wine glass" (39/39):
# Extracted 17000 entries from category wine glass
# Retained 17 countries
# Train: 15300 entries, test: 1700 entries.
# Done generating features and target
# PCA & standardization done. Keeping 449 features
# Done training model in 297.42s
# Done saving model, pca, and scaler to disk
# Category "wine glass"
#
# {'magnification': 1, 'resolution': 32, 'invert_color': True, 'stroke_width_scale': 1}
# [('PH', 13.131313131313133), ('KR', 11.76470588235294), ('TH', 10.0), ('AU', 8.24742268041237), ('US', 8.035714285714286), ('NL', 6.796116504854369), ('RU', 6.315789473684211), ('BR', 6.0), ('PL', 5.88235294117647), ('DE', 5.4945054945054945), ('FR', 4.878048780487805), ('FI', 4.504504504504505), ('GB', 4.25531914893617), ('CZ', 3.79746835443038), ('IT', 3.361344537815126), ('SE', 3.0303030303030303), ('CA', 2.857142857142857)]
#
# Scores greater than 5.88% (random chance):
#   PH: 13.13%
#   KR: 11.76%
#   TH: 10.00%
#   AU: 8.25%
#   US: 8.04%
#   NL: 6.80%
#   RU: 6.32%
#   BR: 6.00%
# Overall accuracy: 0.06%
#
# Finished processing cateogory in 5m9s
