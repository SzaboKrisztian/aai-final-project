# %%
# %load_ext autoreload
# %autoreload 2
from utils import extract_random_entries, complexity_score, render_single, extract_best_entries
import pandas as pd
from IPython.display import display, Image

files = ['./dataset/car.ndjson', './dataset/bicycle.ndjson']
df = pd.concat([extract_best_entries(file, 1000, recognized=True) for file in files], ignore_index=True).sort_values(by='complexity')
print(f'Loaded {len(df)} entries from {files}')
# Out:
# Loaded 2000 entries from ['./dataset/car.ndjson', './dataset/bicycle.ndjson']

# %%
num_pics = 100
step = len(df) // num_pics

img_params = {
    'magnification': 4,
    'resolution': 128,
    'invert_color': False,
    'stroke_width_scale': 2
}

print(df['complexity'].describe())

for i in range(0, len(df), step):
    img = df['drawing'].iloc[i]
    display(Image(render_single(img)))
# Out:
# count    2000.000000
# mean      122.088000
# std        19.494699
# min       105.000000
# 25%       110.000000
# 50%       116.000000
# 75%       127.000000
# max       265.000000
# Name: complexity, dtype: float64
